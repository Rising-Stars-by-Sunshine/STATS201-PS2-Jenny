# %% [markdown]
# Step1: Install the kaggle python library

# %%
# !pip install kaggle

# %% [markdown]
# Step2: Mount the Google Drive to store kaggle API credentials for dataset query

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Step3: Make a directory for kaggle at the temporary instance location on the Google Colab Drive.

# %% [markdown]
# Step4: Go to the kaggle website and download your kaggle API key.
#
# Let's breakdown the steps:
#
# 1)Go to the homepage: https://www.kaggle.com/
#
# 2)Log in your account, click "Your Profile"
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3) In your profile page, click "Account".
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4) Go to the API module in your profile page, and create your API.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When you have your kaggle.json file, please upload here:

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2bc7bb7d-366e-45b9-be77-516786be1eee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2bc7bb7d-366e-45b9-be77-516786be1eee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Now, we got the API access from Kaggle. Let's continue the data query!

# %% [markdown]
# Step5: Make directory name kaggle

# %%
! mkdir ~/.kaggle

# %% [markdown]
# Step6: Upload the json file to Google Drive and copy the json kaggle to the temporary location.

# %%
! cp /content/drive/MyDrive/kaggle.json ~/.kaggle/kaggle.json

# %% [markdown]
# Step7: Change the file permission to read or write for the owner only.

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c ea-twitter-sentiment-classification-2023-2024

# %%
#Downloading dataset not part of competition
! kaggle datasets download -d {die9origephit/climate-change-tweets}
